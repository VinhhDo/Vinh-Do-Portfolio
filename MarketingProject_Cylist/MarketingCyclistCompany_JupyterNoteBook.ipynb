# %% [markdown]
# In this step, we need to ask ourselves. What is the real problem in our project to be solved? That question will guide us for the entire process of analyzing the data.
#     1.How do annual members and casual use cyclistic bikes differently ?
#     2.What do we need to do to convert casual riders into annual members? (Marketing promotion focusing)

# %% [markdown]
# First, I am going to import all the data that I need. However, there are total 12 files as 12 months data of the company. Therefore, I need to combine those dataframe to one dataframe before cleaning and analyzing.

# %%
import pandas as pd
import numpy as np

# %%
from csv import reader

# %% [markdown]
# Import all sources from Jan 2021 to Dec 2021

# %%
dt1 = pd.read_csv(r"C:\Users\Ben\Desktop\Data Analyst Projects\Cyclist - Marketing Project\Cleaned-Tripdata\202101-divvy-tripdata.csv")
dt2= pd.read_csv(r"C:\Users\Ben\Desktop\Data Analyst Projects\Cyclist - Marketing Project\Cleaned-Tripdata\202102-divvy-tripdata.csv")
dt3= pd.read_csv(r"C:\Users\Ben\Desktop\Data Analyst Projects\Cyclist - Marketing Project\Cleaned-Tripdata\202103-divvy-tripdata.csv")
dt4= pd.read_csv(r"C:\Users\Ben\Desktop\Data Analyst Projects\Cyclist - Marketing Project\Cleaned-Tripdata\202104-divvy-tripdata.csv")
dt5=pd.read_csv(r"C:\Users\Ben\Desktop\Data Analyst Projects\Cyclist - Marketing Project\Cleaned-Tripdata\202105-divvy-tripdata.csv")
dt6= pd.read_csv(r"C:\Users\Ben\Desktop\Data Analyst Projects\Cyclist - Marketing Project\Cleaned-Tripdata\202106-divvy-tripdata.csv")
dt7= pd.read_csv(r"C:\Users\Ben\Desktop\Data Analyst Projects\Cyclist - Marketing Project\Cleaned-Tripdata\202107-divvy-tripdata.csv")
dt8= pd.read_csv(r"C:\Users\Ben\Desktop\Data Analyst Projects\Cyclist - Marketing Project\Cleaned-Tripdata\202108-divvy-tripdata.csv")
dt9= pd.read_csv(r"C:\Users\Ben\Desktop\Data Analyst Projects\Cyclist - Marketing Project\Cleaned-Tripdata\202109-divvy-tripdata.csv")
dt10=pd.read_csv(r"C:\Users\Ben\Desktop\Data Analyst Projects\Cyclist - Marketing Project\Cleaned-Tripdata\202110-divvy-tripdata.csv")
dt11= pd.read_csv(r"C:\Users\Ben\Desktop\Data Analyst Projects\Cyclist - Marketing Project\Cleaned-Tripdata\202111-divvy-tripdata.csv")
dt12= pd.read_csv(r"C:\Users\Ben\Desktop\Data Analyst Projects\Cyclist - Marketing Project\Cleaned-Tripdata\202112-divvy-tripdata.csv")

# %%
dt1.head()
# Out:
#             ride_id  rideable_type       started_at         ended_at  \
# 0  E19E6F1B8D4C42ED  electric_bike  1/23/2021 16:14  1/23/2021 16:24
# 1  DC88F20C2C55F27F  electric_bike  1/27/2021 18:43  1/27/2021 18:47
# 2  EC45C94683FE3F27  electric_bike  1/21/2021 22:35  1/21/2021 22:37
# 3  4FA453A75AE377DB  electric_bike   1/7/2021 13:31   1/7/2021 13:42
# 4  BE5E8EB4E7263A0B  electric_bike   1/23/2021 2:24   1/23/2021 2:24
#
#            start_station_name start_station_id end_station_name  \
# 0  California Ave & Cortez St            17660              NaN
# 1  California Ave & Cortez St            17660              NaN
# 2  California Ave & Cortez St            17660              NaN
# 3  California Ave & Cortez St            17660              NaN
# 4  California Ave & Cortez St            17660              NaN
#
#   end_station_id  start_lat  start_lng  end_lat  end_lng member_casual  \
# 0            NaN  41.900341 -87.696743    41.89   -87.72        member
# ...

# %%
dt1.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'ride_lenght', 'day_of_week'],
#       dtype='object')

# %%
dt1.info
# Out:
# <bound method DataFrame.info of                 ride_id  rideable_type       started_at         ended_at  \
# 0      E19E6F1B8D4C42ED  electric_bike  1/23/2021 16:14  1/23/2021 16:24
# 1      DC88F20C2C55F27F  electric_bike  1/27/2021 18:43  1/27/2021 18:47
# 2      EC45C94683FE3F27  electric_bike  1/21/2021 22:35  1/21/2021 22:37
# 3      4FA453A75AE377DB  electric_bike   1/7/2021 13:31   1/7/2021 13:42
# 4      BE5E8EB4E7263A0B  electric_bike   1/23/2021 2:24   1/23/2021 2:24
# ...                 ...            ...              ...              ...
# 96829  B1A5336E1412D8BF   classic_bike  1/19/2021 19:03  1/19/2021 20:10
# 96830  57EA5CB7DCD75F90   classic_bike   1/5/2021 18:42   1/5/2021 19:33
# 96831  815B319A078CC984   classic_bike   1/7/2021 17:59   1/7/2021 19:34
# 96832  6DB04151565CEE63   classic_bike   1/6/2021 19:20   1/6/2021 20:41
# 96833  8008C9C998083A1A    docked_bike  1/17/2021 13:20  1/17/2021 14:17
#
#                     start_station_name start_station_id  \
# ...

# %% [markdown]
# Aggregate all sources from Jan 2021 to Dec 2021

# %%
trip_data = pd.concat([dt1 , dt2 ,dt3, dt4, dt5, dt6, dt7, dt8, dt8, dt10, dt11, dt12])

# %%
trip_data.head()
# Out:
#             ride_id  rideable_type       started_at         ended_at  \
# 0  E19E6F1B8D4C42ED  electric_bike  1/23/2021 16:14  1/23/2021 16:24
# 1  DC88F20C2C55F27F  electric_bike  1/27/2021 18:43  1/27/2021 18:47
# 2  EC45C94683FE3F27  electric_bike  1/21/2021 22:35  1/21/2021 22:37
# 3  4FA453A75AE377DB  electric_bike   1/7/2021 13:31   1/7/2021 13:42
# 4  BE5E8EB4E7263A0B  electric_bike   1/23/2021 2:24   1/23/2021 2:24
#
#            start_station_name start_station_id end_station_name  \
# 0  California Ave & Cortez St            17660              NaN
# 1  California Ave & Cortez St            17660              NaN
# 2  California Ave & Cortez St            17660              NaN
# 3  California Ave & Cortez St            17660              NaN
# 4  California Ave & Cortez St            17660              NaN
#
#   end_station_id  start_lat  start_lng  end_lat  end_lng member_casual  \
# 0            NaN  41.900341 -87.696743    41.89   -87.72        member
# ...

# %%
total_columns = len(trip_data.ride_id)
print(total_columns)
# Out:
# 5643268

# %%
print(trip_data.describe())
# Out:
#           start_lat     start_lng       end_lat       end_lng   day_of_week
# count  5.643268e+06  5.643268e+06  5.638386e+06  5.638386e+06  5.643268e+06
# mean   4.190125e+01 -8.764585e+01  4.190152e+01 -8.764607e+01  4.210475e+00
# std    4.581241e-02  2.845398e-02  4.591948e-02  2.864138e-02  2.121642e+00
# min    4.164000e+01 -8.784000e+01  4.139000e+01 -8.897000e+01  1.000000e+00
# 25%    4.188178e+01 -8.766000e+01  4.188189e+01 -8.766000e+01  2.000000e+00
# 50%    4.189897e+01 -8.764170e+01  4.189993e+01 -8.764182e+01  4.000000e+00
# 75%    4.192914e+01 -8.762772e+01  4.192923e+01 -8.762773e+01  6.000000e+00
# max    4.207000e+01 -8.752000e+01  4.215000e+01 -8.749000e+01  7.000000e+00

# %% [markdown]
# After we combined mutiple dataframe to a data frame, we begin the cleaning stage.
#     1.Deleting unneeded colums.
#     2.I already used excel to define the ride lenght and day of week using columns that those are neccesery data to analyze. Thus, I will move to next step to check for bad data.

# %%
columns = ['start_lat', 'start_lng' , 'end_lat', 'end_lng']
trip_data = trip_data.drop(columns, axis = 1)

# %%
trip_data.head()
# Out:
#             ride_id  rideable_type       started_at         ended_at  \
# 0  E19E6F1B8D4C42ED  electric_bike  1/23/2021 16:14  1/23/2021 16:24
# 1  DC88F20C2C55F27F  electric_bike  1/27/2021 18:43  1/27/2021 18:47
# 2  EC45C94683FE3F27  electric_bike  1/21/2021 22:35  1/21/2021 22:37
# 3  4FA453A75AE377DB  electric_bike   1/7/2021 13:31   1/7/2021 13:42
# 4  BE5E8EB4E7263A0B  electric_bike   1/23/2021 2:24   1/23/2021 2:24
#
#            start_station_name start_station_id end_station_name  \
# 0  California Ave & Cortez St            17660              NaN
# 1  California Ave & Cortez St            17660              NaN
# 2  California Ave & Cortez St            17660              NaN
# 3  California Ave & Cortez St            17660              NaN
# 4  California Ave & Cortez St            17660              NaN
#
#   end_station_id member_casual ride_lenght  day_of_week
# 0            NaN        member     0:10:25            7
# ...

# %%
print(trip_data['ride_lenght'].isna().sum())
print(trip_data['day_of_week'].isna().sum())
# Out:
# 0
# 0

# %% [markdown]
# How many duplicate transaction records are there?

# %%
trip_data['ride_id'].duplicated().sum()
# Out:
# 804363

# %% [markdown]
# Drop the duplicated records

# %%
trip_data = trip_data.drop_duplicates()

trip_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# How many missing values are there?

# %%
trip_data.isnull().sum().sum()
# Out:
# 2475209

# %% [markdown]
# Drop any columns with missing values.

# %%
trip_data = trip_data.dropna()

trip_data.isnull().sum().sum()
# Out:
# 0

# %%
trip_data
# Out:
#                  ride_id  rideable_type       started_at         ended_at  \
# 9       B9F73448DFBE0D45   classic_bike  1/24/2021 19:15  1/24/2021 19:22
# 10      457C7F4B5D3DA135  electric_bike  1/23/2021 12:57  1/23/2021 13:02
# 11      57C750326F9FDABE  electric_bike   1/9/2021 15:28   1/9/2021 15:37
# 12      4D518C65E338D070  electric_bike   1/9/2021 15:28   1/9/2021 15:37
# 13      9D08A3AFF410474D   classic_bike  1/24/2021 15:56  1/24/2021 16:07
# ...                  ...            ...              ...              ...
# 247528  E06135F650553F21  electric_bike  12/7/2021 15:55  12/7/2021 16:00
# 247532  8DF0DBB049906332  electric_bike  12/1/2021 16:50  12/1/2021 16:55
# 247536  CF407BBC3B9FAD63  electric_bike  12/6/2021 19:37  12/6/2021 19:44
# 247537  60BB69EBF5440E92  electric_bike   12/2/2021 8:57   12/2/2021 9:05
# 247539  37AC57E34B2E7E97   classic_bike  12/13/2021 8:45  12/13/2021 8:49
#
#                  start_station_name start_station_id  \
# ...

# %% [markdown]
# Drop any row that we do not need to answer the primary question

# %%
trip_data = trip_data.drop('start_station_id', axis = 1)
trip_data = trip_data.drop('end_station_id', axis = 1)
trip_data
# Out:
#                  ride_id  rideable_type       started_at         ended_at  \
# 9       B9F73448DFBE0D45   classic_bike  1/24/2021 19:15  1/24/2021 19:22
# 10      457C7F4B5D3DA135  electric_bike  1/23/2021 12:57  1/23/2021 13:02
# 11      57C750326F9FDABE  electric_bike   1/9/2021 15:28   1/9/2021 15:37
# 12      4D518C65E338D070  electric_bike   1/9/2021 15:28   1/9/2021 15:37
# 13      9D08A3AFF410474D   classic_bike  1/24/2021 15:56  1/24/2021 16:07
# ...                  ...            ...              ...              ...
# 247528  E06135F650553F21  electric_bike  12/7/2021 15:55  12/7/2021 16:00
# 247532  8DF0DBB049906332  electric_bike  12/1/2021 16:50  12/1/2021 16:55
# 247536  CF407BBC3B9FAD63  electric_bike  12/6/2021 19:37  12/6/2021 19:44
# 247537  60BB69EBF5440E92  electric_bike   12/2/2021 8:57   12/2/2021 9:05
# 247539  37AC57E34B2E7E97   classic_bike  12/13/2021 8:45  12/13/2021 8:49
#
#                  start_station_name            end_station_name member_casual  \
# ...

# %%
trip_data.to_csv(r'C:\Users\Ben\Desktop\Data Analyst Projects\Cyclist - Marketing Project\trip_data.csv', index=False)
